# %%
import pandas as pd

# %%
wb = pd.read_excel("../py/Бизаники.xlsx")

# %%
wb_2 = pd.read_excel("../py/Волфарм1.xlsx")

# %%
wb_2
# Out:
#                       L-лизина эсцинат 0,1% 5 мл №10     145839.5  45200  \
# 0                                     L-Цет таб №100  138800.0063  45474
# 1                                 Q10 МАКС капс. №40  106690.3000  45352
# 2                  Абинекс таб. 1 мг №8 (Каберголин)  171011.0000  45078
# 3     Авикарнитин р-р. 100мг/100мл №1 (Левокарнитин)   81305.4000  45261
# 4                     Авирол-С капс. №12 (Грипп+ОРЗ)   31437.7000  45017
# ...                                              ...          ...    ...
# 1169                Нистатин супп.ваг. 500000 ЕД №10   15371.5900  45231
# 1170                     Нистатин таб. 500000 ЕД №20    7711.5000  45474
# 1171                     Нистатин таб. 500000 ЕД №20    7711.5000  45047
# 1172          Нитазод пор. д/п. сусп. 100мг/5мл 60мл   48422.4000  44713
# 1173                       НИТАСПЕКТ таб. 500 мг №20   69258.0000  45658
#
#                                       Галичфарм,Украина
# ...
